# %%
import numpy as np
import pandas as pd
import xgboost
from sklearn.linear_model import LinearRegression ,ElasticNet, Ridge, Lasso
from sklearn.model_selection import train_test_split
from sklearn.metrics import root_mean_squared_log_error
from sklearn.preprocessing import LabelEncoder
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, AdaBoostRegressor
from catboost import CatBoostClassifier, CatBoostRegressor
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.decomposition import PCA
from sklearn.pipeline import Pipeline

# %%
train = pd.read_csv(r'D:\workspace\MachineLearning\Kaggle_Competition_Data\train.csv', index_col=0)
test = pd.read_csv(r'D:\workspace\MachineLearning\Kaggle_Competition_Data\test.csv', index_col=0)
train

xgb = xgboost.XGBClassifier()

# %%
train.isnull().sum()
le = LabelEncoder()
train['Sex'] = le.fit_transform(train['Sex'])
train

std_scl = StandardScaler().set_output(transform='pandas')
# std_scl.fit(train)

# train = std_scl.transform(train)

# %%
test.isnull().sum()
X,y = train.drop('Calories', axis=1), train['Calories']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=25)

# %%
# el = ElasticNet(alpha=0.2, l1_ratio=0.2)
# el.fit(X_train, y_train)
# y_pred = el.predict(X_test)
# y_pred = np.maximum(0, y_pred)
# root_mean_squared_log_error(np.maximum(0, y_test), y_pred)

# %%
# gbm = CatBoostRegressor(random_state=25, verbose=0)
# gbm.fit(X_train, y_train)
# y_pred = gbm.predict(X_test)
# y_pred = np.maximum(0, y_pred)
# root_mean_squared_log_error(np.maximum(0, y_test), y_pred)

# %%
# prcomp = PCA(n_components=0.90).set_output(transform='pandas')
# components = prcomp.fit_transform(X)
# components

# %%
# total_var = np.sum(prcomp.explained_variance_)
# (prcomp.explained_variance_)/total_var
# percentage_var = (prcomp.explained_variance_*100)/total_var
# prcomp.explained_variance_ratio_
# prcomp.explained_variance_ratio_*100
# np.cumsum(prcomp.explained_variance_ratio_*100)

# %%
# prcomp.components_

# %%
# X_train_pca, X_test_pca, y_train, y_test = train_test_split(components, y, test_size=0.3, random_state=25)

# %%
# gbm.fit(X_train_pca, y_train)

# %%
# y_pred = gbm.predict(X_test_pca)
# y_pred = np.maximum(0, y_pred)
# root_mean_squared_log_error(y_test, y_pred)

# %%
# gbm = CatBoostRegressor(random_state=25, max_depth=10)
# gbm.fit(X_train_pca, y_train)
# y_pred = gbm.predict(X_test_pca)
# y_pred = np.maximum(0, y_pred)

# root_mean_squared_log_error(y_test, y_pred)

# %%
# depths = np.arange(1,101,1)
# loss=[]

# for i in depths:
#     dtr = DecisionTreeRegressor(max_depth=i)
#     dtr.fit(X_train, y_train)
#     y_pred = dtr.predict(X_test)
#     loss.append([i, root_mean_squared_log_error(y_test, y_pred)])

# loss_df = pd.DataFrame(loss, columns=['Depth', 'Loss'])
# loss_df.sort_values('Loss')

# %%
# dtr = DecisionTreeRegressor(random_state=25)
# dtr.fit(X_train, y_train)
# y_pred = dtr.predict(X_test)
# root_mean_squared_log_error(y_test, y_pred)

# %%
# rf = RandomForestRegressor(max_depth=20)
# rf.fit(X_train, y_train)
# y_pred = rf.predict(X_test)
# root_mean_squared_log_error(y_test, y_pred)

# %%
# abc = AdaBoostRegressor(n_estimators=30)
# abc.fit(X_train, y_train)
# y_pred = abc.predict(X_test)

# root_mean_squared_log_error(y_test, y_pred)

# %%
# cat_cols = [col for col in X_train.columns if X_train[col].dtype == 'object']
# gbm = CatBoostRegressor(verbose=0, cat_features=cat_cols)
# gbm.fit(X_train, y_train)
# y_pred = gbm.predict(X_test)

# %%
# root_mean_squared_log_error(y_test, y_pred)
# Out:
# 0.060662484490246124

# %%
cat_cols = [col for col in X_train.columns if X_train[col].dtype == 'object']
gbm = CatBoostRegressor(verbose=0, cat_features=cat_cols)
pipe = Pipeline([('S_SC',std_scl),('CatBoost',gbm)])

# %%
pipe.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('S_SC', StandardScaler()),
#                 ('CatBoost',
#                  <catboost.core.CatBoostRegressor object at 0x00000218AA28DAC0>)])

# %%
y_pred = pipe.predict(X_test)

# %%
y_pred[y_pred<0] = 0

# %%
root_mean_squared_log_error(y_test, y_pred)
# Out:
# 0.06066248440912634
